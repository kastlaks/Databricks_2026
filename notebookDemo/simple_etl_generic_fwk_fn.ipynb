# %%
# %run /Workspace/Users/inceptezwd33we44@gmail.com/iz_wd37_databricks_repo/notebookDemo/generic_functions_nb1

# %%
print(return_df)

# %%
# this step is not needed , since spark session already avaialable 

spark2=return_sparksession("Wd_37_simple_ETL")

# %%
print(spark)
print(spark2)

# %%
src_path='/Volumes/izwd37dev/wd37db/rawdatta/custs_header'
cust_df=return_df(spark2,src_path,"csv",",",True,True,True)

cust_df.show(5)

# %%
cust_df=return_df(spark2,src_path,infsch=True)

cust_df.show(5)

# %%
# filter all pilot data write into json format

pilot_df=cust_df.filter("profession ='Pilot'")

pilot_df.count()

write_df(pilot_df,'/Volumes/izwd37dev/wd37db/rawdatta/cust_josn_pilot','json')

# %%
write_df(pilot_df,"izwd37dev.wd37db.cust_json_pilot",'tbl')

# %%
# %sql

select count(1) from izwd37dev.wd37db.cust_json_pilot
