# %% [markdown]
# Call child Notebook in the impl /main Notebook
#
# How to call child / other noteboook from main notebook
#
#
# 1. %run
#
# - we will use load all functions / var in the main notebook itself , for accesing
#
# -- we are runnning notebook locally / inline
# -- we cant pass parameter
#
# 2. dbutils.notebook.run()
#
# -- this will invoke notebook as seprate instance / seprate job
#
# -- pass arguments , capture the resturn value in string format

# %%
mypar_value="passing from caller ....."

# %%
# %run ./child_util_nb

# %%
print(get_seq_number(10))

# %%
print_line(1000)

# %%
# dbutils.help()
# path , timeout in sec , parameter
dbutils.notebook.run("./child_dbutil_nb",100)

# %%
# %run ./child_dbutil_nb

# %%
get_msg()

# %%
db_name="wd37"

user_name="izuser_wd37"
range_num="3"



# pass parameter to the NB

ret_value=dbutils.notebook.run("./child_dbutil_nb",timeout_seconds=100,arguments={"dbname":db_name,"cur_user":user_name,"range_nm":range_num})

print(ret_value)

print(type(ret_value))

# %%
import myutil_test as t

t.get_msg()
